# %% [markdown]
# <a href="https://colab.research.google.com/github/RickLiu2025/hello-agents/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Fri Jan  9 22:42:16 2026

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# ''

# %%
from google.colab import drive
drive.mount('/MyDrive')
# Out:
# Mounted at /MyDrive
